# %% [markdown]
# # The Iris dataset

# %% [markdown]
# The Iris dataset is a classic dataset fromthe 1930s; it is one of the first modern examples of statistical classification. The setting is that of Iris flowers, of which there are multiple species that can be identified by their morphology. The following four attributes of each plant were measured :
# - Sepal length
# - Sepal width
# - Petal length
# - Petal width

# %% [markdown]
# our goal make a good prediction about its species from its measurements

# %% [markdown]
# # First step : visualization

# %%
from matplotlib import pyplot as plt
from sklearn.datasets import load_iris
import numpy as np
# %matplotlib inline

# We load the data with load_iris from sklearn
data = load_iris()
features = data['data']
feature_names = data['feature_names']
target = data['target']

for t, marker, c in zip(xrange(3), ">ox", "rgb"):
    # We plot each class on its own to get different colored markers
    plt.scatter(features[target == t, 0],
                features[target == t, 1],
                marker = marker,
                c = c)

# %%
fig, axes = plt.subplots(2,3)
for t, marker, c in zip(xrange(3), ">ox", "rgb"):
# We plot each class on its own to get different colored markers
    axes[0,0].scatter(features[target == t, 0],
                features[target == t, 1],
                marker = marker,
                c = c)
    axes[0,1].scatter(features[target == t, 0],
                features[target == t, 2],
                marker = marker,
                c = c)
    axes[0,2].scatter(features[target == t, 0],
                features[target == t, 3],
                marker = marker,
                c = c)
    axes[1,0].scatter(features[target == t, 1],
                features[target == t, 2],
                marker = marker,
                c = c)
    axes[1,1].scatter(features[target == t, 1],
                features[target == t, 3],
                marker = marker,
                c = c)
    axes[1,2].scatter(features[target == t, 2],
                features[target == t, 3],
                marker = marker,
                c = c)

# %% [markdown]
# # Building classification model
